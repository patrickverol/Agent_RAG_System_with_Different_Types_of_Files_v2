# %%
import yfinance as yf

# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.64-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\pichau\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (1.5.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\pichau\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (1.23.5)
# Collecting requests>=2.31 (from yfinance)
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\pichau\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (3.11.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\pichau\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2022.6)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.6-py311-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.1.tar.gz (3.0 MB)
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#       --------------------------------------- 0.1/3.0 MB 1.7 MB/s eta 0:00:02
#      ------ --------------------------------- 0.5/3.0 MB 6.4 MB/s eta 0:00:01
#      ------------------ --------------------- 1.4/3.0 MB 11.2 MB/s eta 0:00:01
#      ------------------------------ --------- 2.3/3.0 MB 13.3 MB/s eta 0:00:01
#      ---------------------------------------  3.0/3.0 MB 13.7 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 12.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Downloading curl_cffi-0.11.4-cp39-abi3-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\pichau\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (3.20.3)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-15.0.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.11.1->yfinance)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\pichau\appdata\roaming\python\python311\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.14.0)
# Collecting cffi>=1.12.0 (from curl_cffi>=0.7->yfinance)
#   Downloading cffi-1.17.1-cp311-cp311-win_amd64.whl.metadata (1.6 kB)
# Collecting certifi>=2024.2.2 (from curl_cffi>=0.7->yfinance)
#   Using cached certifi-2025.6.15-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\pichau\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pichau\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pichau\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pichau\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (1.26.13)
# Collecting pycparser (from cffi>=1.12.0->curl_cffi>=0.7->yfinance)
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: six>=1.5 in c:\users\pichau\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.3.0->yfinance) (1.16.0)
# Downloading yfinance-0.2.64-py2.py3-none-any.whl (119 kB)
#    ---------------------------------------- 0.0/119.4 kB ? eta -:--:--
#    ---------------------------------------- 119.4/119.4 kB 3.5 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
#    ---------------------------------------- 0.0/187.3 kB ? eta -:--:--
#    --------------------------------------- 187.3/187.3 kB 11.1 MB/s eta 0:00:00
# Downloading curl_cffi-0.11.4-cp39-abi3-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------- ----------- 1.2/1.6 MB 24.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 20.4 MB/s eta 0:00:00
# Downloading frozendict-2.4.6-py311-none-any.whl (16 kB)
# Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.8 kB ? eta -:--:--
#    ---------------------------------------- 64.8/64.8 kB 3.6 MB/s eta 0:00:00
# Downloading websockets-15.0.1-cp311-cp311-win_amd64.whl (176 kB)
#    ---------------------------------------- 0.0/176.8 kB ? eta -:--:--
#    --------------------------------------- 176.8/176.8 kB 11.1 MB/s eta 0:00:00
# Using cached certifi-2025.6.15-py3-none-any.whl (157 kB)
# Downloading cffi-1.17.1-cp311-cp311-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/181.4 kB ? eta -:--:--
#    --------------------------------------- 181.4/181.4 kB 10.7 MB/s eta 0:00:00
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#    ---------------------------------------- 0.0/117.6 kB ? eta -:--:--
#    ---------------------------------------- 117.6/117.6 kB 7.2 MB/s eta 0:00:00
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.18.1-py3-none-any.whl size=139097 sha256=231bd707e7c35bf5b46dbc60adf6449597eb9c0a44a24eda440884ad462d5c92
#   Stored in directory: c:\users\pichau\appdata\local\pip\cache\wheels\25\cb\79\a133a0d1d75f318a96614ed7fb97bdf2f35a7b6c4d4e426e3f
# Successfully built peewee
# Installing collected packages: peewee, multitasking, websockets, soupsieve, pycparser, frozendict, certifi, requests, cffi, beautifulsoup4, curl_cffi, yfinance
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2022.9.24
#     Uninstalling certifi-2022.9.24:
#       Successfully uninstalled certifi-2022.9.24
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
# Successfully installed beautifulsoup4-4.13.4 certifi-2025.6.15 cffi-1.17.1 curl_cffi-0.11.4 frozendict-2.4.6 multitasking-0.0.11 peewee-3.18.1 pycparser-2.22 requests-2.32.4 soupsieve-2.7 websockets-15.0.1 yfinance-0.2.64
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Create Ticker object
ticker = yf.Ticker('AMZN')

# Get basic info
info = ticker.info

# Get current price data
hist = ticker.history(period="30d")

# %%
display(info)
display(hist)
# Out:
# {'address1': '410 Terry Avenue North',
#  'city': 'Seattle',
#  'state': 'WA',
#  'zip': '98109-5210',
#  'country': 'United States',
#  'phone': '206 266 1000',
#  'website': 'https://www.aboutamazon.com',
#  'industry': 'Internet Retail',
#  'industryKey': 'internet-retail',
#  'industryDisp': 'Internet Retail',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
#  'longBusinessSummary': "Amazon.com, Inc. engages in the retail sale of consumer products, advertising, and subscriptions service through online and physical stores in North America and internationally. The company operates through three segments: North America, International, and Amazon Web Services (AWS). It also manufactures and sells electronic devices, including Kindle, fire tablets, fire TVs, echo, ring, blink, and eero; and develops and produces media content. In addition, the company offers programs that enable sellers to sell their products in its stores; and programs that allow authors, independent publishers, musicians, filmmakers, Twitch streamers, skill and app developers, and others to publish and sell content. Further, it provides compute, storage, database, analytics, machine learning, and other services, as well as advertising services through programs, such as sponsored ads, display, and video advertising. Additionally, the company offers Amazon Prime, a membership program. The company's products offered through its stores include merchandise and content purchased for resale and products offered by third-party sellers. It serves consumers, sellers, developers, enterprises, content creators, advertisers, and employees. Amazon.com, Inc. was incorporated in 1994 and is headquartered in Seattle, Washington.",
#  'fullTimeEmployees': 1560000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Jeffrey P. Bezos',
#    'age': 60,
#    'title': 'Founder & Executive Chairman',
#    'yearBorn': 1964,
#    'fiscalYear': 2024,
#    'totalPay': 1681840,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Andrew R. Jassy',
#    'age': 56,
#    'title': 'President, CEO & Director',
#    'yearBorn': 1968,
#    'fiscalYear': 2024,
#    'totalPay': 1596889,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Brian T. Olsavsky',
#    'age': 60,
#    'title': 'Senior VP & CFO',
#    'yearBorn': 1964,
#    'fiscalYear': 2024,
#    'totalPay': 371900,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. David A. Zapolsky J.D.',
#    'age': 60,
#    'title': 'Senior VP, Chief Global Affairs & Legal Officer',
#    'yearBorn': 1964,
#    'fiscalYear': 2024,
#    'totalPay': 371900,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Douglas J. Herrington',
#    'age': 57,
#    'title': 'Chief Executive Officer of Worldwide Amazon Stores',
#    'yearBorn': 1967,
#    'fiscalYear': 2024,
#    'totalPay': 386435,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Matthew S. Garman',
#    'age': 47,
#    'title': 'Chief Executive Officer of Amazon Web Series',
#    'yearBorn': 1977,
#    'fiscalYear': 2024,
#    'totalPay': 384275,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Shelley L. Reynolds',
#    'age': 59,
#    'title': 'VP, Worldwide Controller & Principal Accounting Officer',
#    'yearBorn': 1965,
#    'fiscalYear': 2024,
#    'totalPay': 163200,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Werner  Vogels',
#    'title': 'Chief Technology Officer',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Dave  Fildes',
#    'title': 'Director of Investor Relations',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Anuradha  Aggarwal',
#    'title': 'CMO & Director of User Growth',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 2,
#  'boardRisk': 8,
#  'compensationRisk': 10,
#  'shareHolderRightsRisk': 3,
#  'overallRisk': 9,
#  'governanceEpochDate': 1748736000,
#  'compensationAsOfEpochDate': 1735603200,
#  'irWebsite': 'http://phx.corporate-ir.net/phoenix.zhtml?c=97664&p=irol-irhome',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 223.3,
#  'open': 223.52,
#  'dayLow': 219.12,
#  'dayHigh': 223.82,
#  'regularMarketPreviousClose': 223.3,
#  'regularMarketOpen': 223.52,
#  'regularMarketDayLow': 219.12,
#  'regularMarketDayHigh': 223.82,
#  'payoutRatio': 0.0,
#  'beta': 1.334,
#  'trailingPE': 35.73127,
#  'forwardPE': 35.67317,
#  'volume': 58738736,
#  'regularMarketVolume': 58738736,
#  'averageVolume': 50408891,
#  'averageVolume10days': 49146930,
#  'averageDailyVolume10Day': 49146930,
#  'bid': 219.25,
#  'ask': 219.56,
#  'bidSize': 5,
#  'askSize': 5,
#  'marketCap': 2329131876352,
#  'fiftyTwoWeekLow': 151.61,
#  'fiftyTwoWeekHigh': 242.52,
#  'priceToSalesTrailing12Months': 3.5815551,
#  'fiftyDayAverage': 200.9472,
#  'twoHundredDayAverage': 204.93195,
#  'trailingAnnualDividendRate': 0.0,
#  'trailingAnnualDividendYield': 0.0,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 2392509644800,
#  'profitMargins': 0.1014,
#  'floatShares': 9571703330,
#  'sharesOutstanding': 10616399872,
#  'sharesShort': 61836013,
#  'sharesShortPriorMonth': 71501108,
#  'sharesShortPreviousMonthDate': 1747267200,
#  'dateShortInterest': 1749772800,
#  'sharesPercentSharesOut': 0.0058,
#  'heldPercentInsiders': 0.08721,
#  'heldPercentInstitutions': 0.65492,
#  'shortRatio': 1.62,
#  'shortPercentOfFloat': 0.0064,
#  'impliedSharesOutstanding': 10616399872,
#  'bookValue': 28.82,
#  'priceToBook': 7.612422,
#  'lastFiscalYearEnd': 1735603200,
#  'nextFiscalYearEnd': 1767139200,
#  'mostRecentQuarter': 1743379200,
#  'earningsQuarterlyGrowth': 0.642,
#  'netIncomeToCommon': 65943998464,
#  'trailingEps': 6.14,
#  'forwardEps': 6.15,
#  'lastSplitFactor': '20:1',
#  'lastSplitDate': 1654473600,
#  'enterpriseToRevenue': 3.679,
#  'enterpriseToEbitda': 18.966,
#  '52WeekChange': 0.13235295,
#  'SandP52WeekChange': 0.12748289,
#  'quoteType': 'EQUITY',
#  'currentPrice': 219.39,
#  'targetHighPrice': 305.0,
#  'targetLowPrice': 195.0,
#  'targetMeanPrice': 241.81862,
#  'targetMedianPrice': 240.0,
#  'recommendationMean': 1.37143,
#  'recommendationKey': 'strong_buy',
#  'numberOfAnalystOpinions': 65,
#  'totalCash': 94564999168,
#  'totalCashPerShare': 8.907,
#  'ebitda': 126144004096,
#  'totalDebt': 157952999424,
#  'quickRatio': 0.807,
#  'currentRatio': 1.048,
#  'totalRevenue': 650313007104,
#  'debtToEquity': 51.641,
#  'revenuePerShare': 61.785,
#  'returnOnAssets': 0.07632,
#  'returnOnEquity': 0.2524,
#  'grossProfits': 319681986560,
#  'freeCashflow': 39273500672,
#  'operatingCashflow': 113903001600,
#  'earningsGrowth': 0.622,
#  'revenueGrowth': 0.086,
#  'grossMargins': 0.49158,
#  'ebitdaMargins': 0.19397,
#  'operatingMargins': 0.11823,
#  'financialCurrency': 'USD',
#  'symbol': 'AMZN',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'corporateActions': [],
#  'postMarketTime': 1751327998,
#  'regularMarketTime': 1751313601,
#  'postMarketChangePercent': 0.027347445,
#  'postMarketPrice': 219.45,
#  'postMarketChange': 0.05999756,
#  'regularMarketChange': -3.9100037,
#  'regularMarketDayRange': '219.12 - 223.82',
#  'fullExchangeName': 'NasdaqGS',
#  'averageDailyVolume3Month': 50408891,
#  'fiftyTwoWeekLowChange': 67.78,
#  'fiftyTwoWeekLowChangePercent': 0.44706813,
#  'fiftyTwoWeekRange': '151.61 - 242.52',
#  'fiftyTwoWeekHighChange': -23.130005,
#  'fiftyTwoWeekHighChangePercent': -0.09537359,
#  'fiftyTwoWeekChangePercent': 13.235294,
#  'earningsTimestamp': 1746129660,
#  'earningsTimestampStart': 1753905600,
#  'earningsTimestampEnd': 1754337600,
#  'earningsCallTimestampStart': 1746133200,
#  'earningsCallTimestampEnd': 1746133200,
#  'isEarningsDateEstimate': True,
#  'epsTrailingTwelveMonths': 6.14,
#  'epsForward': 6.15,
#  'epsCurrentYear': 6.21447,
#  'priceEpsCurrentYear': 35.303093,
#  'fiftyDayAverageChange': 18.442795,
#  'fiftyDayAverageChangePercent': 0.09177931,
#  'regularMarketChangePercent': -1.7510092,
#  'regularMarketPrice': 219.39,
#  'exchange': 'NMS',
#  'messageBoardId': 'finmb_18749',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'marketState': 'POSTPOST',
#  'shortName': 'Amazon.com, Inc.',
#  'longName': 'Amazon.com, Inc.',
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 863703000000,
#  'twoHundredDayAverageChange': 14.458054,
#  'twoHundredDayAverageChangePercent': 0.07055051,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'averageAnalystRating': '1.4 - Strong Buy',
#  'cryptoTradeable': False,
#  'displayName': 'Amazon.com',
#  'trailingPegRatio': 2.8828}
#                                  Open        High         Low       Close  \
# Date
# 2025-05-16 00:00:00-04:00  206.850006  206.850006  204.369995  205.589996
# 2025-05-19 00:00:00-04:00  201.649994  206.619995  201.259995  206.160004
# 2025-05-20 00:00:00-04:00  204.630005  205.589996  202.649994  204.070007
# 2025-05-21 00:00:00-04:00  201.610001  203.460007  200.059998  201.119995
# 2025-05-22 00:00:00-04:00  201.380005  205.759995  200.160004  203.100006
# 2025-05-23 00:00:00-04:00  198.899994  202.369995  197.850006  200.990005
# 2025-05-27 00:00:00-04:00  203.089996  206.690002  202.190002  206.020004
# 2025-05-28 00:00:00-04:00  205.919998  207.660004  204.410004  204.720001
# 2025-05-29 00:00:00-04:00  208.029999  208.809998  204.229996  205.699997
# 2025-05-30 00:00:00-04:00  204.839996  205.990005  201.699997  205.009995
# 2025-06-02 00:00:00-04:00  204.979996  207.000000  202.679993  206.649994
# 2025-06-03 00:00:00-04:00  207.110001  208.949997  205.029999  205.710007
# 2025-06-04 00:00:00-04:00  206.550003  208.179993  205.179993  207.229996
# 2025-06-05 00:00:00-04:00  209.550003  212.809998  207.559998  207.910004
# 2025-06-06 00:00:00-04:00  212.399994  213.869995  210.500000  213.570007
# 2025-06-09 00:00:00-04:00  214.750000  217.850006  212.880005  216.979996
# 2025-06-10 00:00:00-04:00  216.779999  217.690002  214.149994  217.610001
# 2025-06-11 00:00:00-04:00  217.410004  218.399994  212.889999  213.199997
# 2025-06-12 00:00:00-04:00  211.779999  213.580002  211.330002  213.240005
# 2025-06-13 00:00:00-04:00  209.960007  214.050003  209.619995  212.100006
# 2025-06-16 00:00:00-04:00  212.309998  217.059998  211.600006  216.100006
# 2025-06-17 00:00:00-04:00  215.199997  217.410004  214.559998  214.820007
# 2025-06-18 00:00:00-04:00  215.089996  217.960007  212.339996  212.520004
# 2025-06-20 00:00:00-04:00  214.679993  214.889999  208.270004  209.690002
# 2025-06-23 00:00:00-04:00  209.789993  210.389999  207.309998  208.470001
# 2025-06-24 00:00:00-04:00  212.139999  214.339996  211.050003  212.770004
# 2025-06-25 00:00:00-04:00  214.619995  216.029999  211.110001  211.990005
# 2025-06-26 00:00:00-04:00  213.119995  218.039993  212.009995  217.119995
# 2025-06-27 00:00:00-04:00  219.919998  223.300003  216.740005  223.300003
# 2025-06-30 00:00:00-04:00  223.520004  223.820007  219.119995  219.389999
#
#                               Volume  Dividends  Stock Splits
# Date
# 2025-05-16 00:00:00-04:00   43318500        0.0           0.0
# 2025-05-19 00:00:00-04:00   34314800        0.0           0.0
# 2025-05-20 00:00:00-04:00   29470400        0.0           0.0
# 2025-05-21 00:00:00-04:00   42460900        0.0           0.0
# 2025-05-22 00:00:00-04:00   38938900        0.0           0.0
# 2025-05-23 00:00:00-04:00   33393500        0.0           0.0
# 2025-05-27 00:00:00-04:00   34892000        0.0           0.0
# 2025-05-28 00:00:00-04:00   28549800        0.0           0.0
# 2025-05-29 00:00:00-04:00   34650000        0.0           0.0
# 2025-05-30 00:00:00-04:00   51679400        0.0           0.0
# 2025-06-02 00:00:00-04:00   29113300        0.0           0.0
# 2025-06-03 00:00:00-04:00   33139100        0.0           0.0
# 2025-06-04 00:00:00-04:00   29915600        0.0           0.0
# 2025-06-05 00:00:00-04:00   51864200        0.0           0.0
# 2025-06-06 00:00:00-04:00   39832500        0.0           0.0
# 2025-06-09 00:00:00-04:00   38102500        0.0           0.0
# 2025-06-10 00:00:00-04:00   31303300        0.0           0.0
# 2025-06-11 00:00:00-04:00   39326000        0.0           0.0
# 2025-06-12 00:00:00-04:00   27640000        0.0           0.0
# 2025-06-13 00:00:00-04:00   29337800        0.0           0.0
# 2025-06-16 00:00:00-04:00   33284200        0.0           0.0
# 2025-06-17 00:00:00-04:00   32086300        0.0           0.0
# 2025-06-18 00:00:00-04:00   44360500        0.0           0.0
# 2025-06-20 00:00:00-04:00   75350700        0.0           0.0
# 2025-06-23 00:00:00-04:00   37311700        0.0           0.0
# 2025-06-24 00:00:00-04:00   38378800        0.0           0.0
# 2025-06-25 00:00:00-04:00   31755700        0.0           0.0
# 2025-06-26 00:00:00-04:00   50480800        0.0           0.0
# 2025-06-27 00:00:00-04:00  119122800        0.0           0.0
# 2025-06-30 00:00:00-04:00   58738736        0.0           0.0

# %%
# Convert to list of dictionaries
stock_data_list = []
for date, row in hist.iterrows():
    stock_data = {
        'date': date.date(),
        'open': float(row['Open']),
        'high': float(row['High']),
        'low': float(row['Low']),
        'close': float(row['Close']),
        'volume': int(row['Volume']),
        'dividends': float(row['Dividends']),
        'stock_splits': float(row['Stock Splits'])
    }
    stock_data_list.append(stock_data)

# %%
print(stock_data_list)
# Out:
# [{'date': datetime.date(2025, 5, 19), 'open': 30.908602009071565, 'high': 31.160994741633885, 'low': 30.772697945145083, 'close': 31.044506072998047, 'volume': 30200500, 'dividends': 0.0, 'stock_splits': 0.0}, {'date': datetime.date(2025, 5, 20), 'open': 31.112457702820386, 'high': 31.46192740731888, 'low': 31.015384430729895, 'close': 31.170703887939453, 'volume': 33485800, 'dividends': 0.0, 'stock_splits': 0.0}, {'date': datetime.date(2025, 5, 21), 'open': 31.267776719690026, 'high': 31.442511569478505, 'low': 30.762989416644807, 'close': 30.82123374938965, 'volume': 28724100, 'dividends': 0.0, 'stock_splits': 0.0}, {'date': datetime.date(2025, 5, 22), 'open': 30.71445203649333, 'high': 30.72415973422627, 'low': 30.297030291747028, 'close': 30.41352081298828, 'volume': 42207300, 'dividends': 0.0, 'stock_splits': 0.0}, {'date': datetime.date(2025, 5, 23), 'open': 30.18054080007188, 'high': 30.48147201538086, 'low': 29.96697701042583, 'close': 30.48147201538086, 'volume': 25732400, 'dividends': 0.0, 'stock_splits': 0.0}, {'date': datetime.date(2025, 5, 26), 'open': 30.539716966243656, 'high': 30.607670849897698, 'low': 30.22907804718408, 'close': 30.384397506713867, 'volume': 21277100, 'dividends': 0.0, 'stock_splits': 0.0}, {'date': datetime.date(2025, 5, 27), 'open': 30.597962132980776, 'high': 30.743573889995215, 'low': 30.44264267862485, 'close': 30.607669830322266, 'volume': 34361500, 'dividends': 0.0, 'stock_splits': 0.0}, {'date': datetime.date(2025, 5, 28), 'open': 30.74357450787152, 'high': 30.792111144000494, 'low': 30.510595321655273, 'close': 30.510595321655273, 'volume': 30516200, 'dividends': 0.0, 'stock_splits': 0.0}, {'date': datetime.date(2025, 5, 29), 'open': 30.559131987959972, 'high': 30.578547383052328, 'low': 30.14171025124427, 'close': 30.326152801513672, 'volume': 20778800, 'dividends': 0.0, 'stock_splits': 0.0}, {'date': datetime.date(2025, 5, 30), 'open': 30.238784441194095, 'high': 30.355274956596304, 'low': 29.996097564697266, 'close': 29.996097564697266, 'volume': 45127700, 'dividends': 0.0, 'stock_splits': 0.0}, {'date': datetime.date(2025, 6, 2), 'open': 30.714451693746653, 'high': 30.724159391371266, 'low': 30.102881555828212, 'close': 30.170833587646484, 'volume': 35111000, 'dividends': 0.0, 'stock_splits': 0.0}, {'date': datetime.date(2025, 6, 3), 'open': 29.8799991607666, 'high': 30.299999237060547, 'low': 29.389999389648438, 'close': 30.18000030517578, 'volume': 59828700, 'dividends': 0.909166, 'stock_splits': 0.0}, {'date': datetime.date(2025, 6, 4), 'open': 30.239999771118164, 'high': 30.450000762939453, 'low': 29.270000457763672, 'close': 29.350000381469727, 'volume': 41952900, 'dividends': 0.0, 'stock_splits': 0.0}, {'date': datetime.date(2025, 6, 5), 'open': 29.5, 'high': 29.639999389648438, 'low': 29.209999084472656, 'close': 29.360000610351562, 'volume': 23774000, 'dividends': 0.0, 'stock_splits': 0.0}, {'date': datetime.date(2025, 6, 6), 'open': 29.450000762939453, 'high': 29.829999923706055, 'low': 29.360000610351562, 'close': 29.670000076293945, 'volume': 28069300, 'dividends': 0.0, 'stock_splits': 0.0}, {'date': datetime.date(2025, 6, 9), 'open': 29.219999313354492, 'high': 29.469999313354492, 'low': 28.860000610351562, 'close': 29.170000076293945, 'volume': 43834800, 'dividends': 0.0, 'stock_splits': 0.0}, {'date': datetime.date(2025, 6, 10), 'open': 29.40999984741211, 'high': 30.219999313354492, 'low': 29.350000381469727, 'close': 30.049999237060547, 'volume': 46241800, 'dividends': 0.0, 'stock_splits': 0.0}, {'date': datetime.date(2025, 6, 11), 'open': 30.299999237060547, 'high': 31.15999984741211, 'low': 30.299999237060547, 'close': 31.049999237060547, 'volume': 52432400, 'dividends': 0.0, 'stock_splits': 0.0}, {'date': datetime.date(2025, 6, 12), 'open': 30.799999237060547, 'high': 31.90999984741211, 'low': 30.729999542236328, 'close': 31.75, 'volume': 51729500, 'dividends': 0.0, 'stock_splits': 0.0}, {'date': datetime.date(2025, 6, 13), 'open': 33.11000061035156, 'high': 33. ...

# %%
# Stock symbols to fetch data for
STOCK_SYMBOLS = [
    'AAPL', 'MSFT', 'AMZN', 'GOOGL', 'TSLA', 'META', 'NFLX', 'ADBE', 
    'CRM', 'ORCL', 'NVDA', 'INTC', 'CSCO', 'IBM', 'HPQ', 'DELL', 
    'VMW', 'NOW', 'WDAY', 'SNOW'
]
